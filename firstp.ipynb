# %% [markdown]
# <a href="https://colab.research.google.com/github/123Ranjan/AI-Powered-Workforce-Analytics-Talent-Intelligence-Dashboard-/blob/main/firstp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Ranjan!")

a = 10
b = 20

print("Sum =", a + b)
# Out:
# Hello, Ranjan!
# Sum = 30
